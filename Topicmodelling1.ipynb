# %%
# INSTALL
# !pip install bertopic --upgrade bertopic
# Out:
# Collecting bertopic
#   Downloading bertopic-0.16.3-py3-none-any.whl.metadata (23 kB)
# Collecting hdbscan>=0.8.29 (from bertopic)
#   Downloading hdbscan-0.8.37-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.25.2)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (2.0.3)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.15.0)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.2.2)
# Collecting sentence-transformers>=0.4.1 (from bertopic)
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.66.4)
# Collecting umap-learn>=0.5.0 (from bertopic)
#   Downloading umap_learn-0.5.6-py3-none-any.whl.metadata (21 kB)
# Collecting cython<3,>=0.27 (from hdbscan>=0.8.29->bertopic)
#   Downloading Cython-0.29.37-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (3.1 kB)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.11.4)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (24.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.5.0)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.42.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.3.1+cu121)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (9.4.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.58.1)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2023.6.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (4.12.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.41.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=0.4.1->bertopic) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=0.4.1->bertopic) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=0.4.1->bertopic) (0.19.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Downloading bertopic-0.16.3-py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 9.7 MB/s eta 0:00:00
# Downloading hdbscan-0.8.37-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 34.0 MB/s eta 0:00:00
# Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 21.9 MB/s eta 0:00:00
# Downloading umap_learn-0.5.6-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 9.0 MB/s eta 0:00:00
# Downloading Cython-0.29.37-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 73.6 MB/s eta 0:00:00
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 6.0 MB/s eta 0:00:00
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 17.4 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, cython, nvidia-cusparse-cu12, nvidia-cudnn-cu12, pynndescent, nvidia-cusolver-cu12, hdbscan, umap-learn, sentence-transformers, bertopic
#   Attempting uninstall: cython
#     Found existing installation: Cython 3.0.10
#     Uninstalling Cython-3.0.10:
#       Successfully uninstalled Cython-3.0.10
# Successfully installed bertopic-0.16.3 cython-0.29.37 hdbscan-0.8.37 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 pynndescent-0.5.13 sentence-transformers-3.0.1 umap-learn-0.5.6

# %% [markdown]
# # 1. Set up - Import libraries, mount drive and check directory

# %%
# Import
import pandas as pd # pandas dataframe
import os # operating system

# Mount drive
from google.colab import drive
drive.mount('/content/gdrive')

# Change directory
os.chdir('/content/gdrive/MyDrive/RDS_Bert_2024/BERT_20240704')

# Check drive
print (os.getcwd())
print(os.listdir())
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive/RDS_Bert_2024/BERT_20240704
# ['RawData.csv', 'Example_2.csv', 'Example_2.gsheet', 'RawData_without_stopwords.csv', 'Screening_Model_v1', 'RawData.gsheet', 'RawData_without_stopwords.gsheet', 'Topicmodelling1.ipynb']

# %% [markdown]
#  # 2. Preprocessing - Import NLKT library, import/download stopwords - remove these words from the text, load CSV file

# %%
# Preprocessing - Import NLTK library (Natural Language Toolkit) - a library used for NLP
# Import and download stopwords (common words such as - and, it, is, - are removed in text processing)
# Load CSV file and remove the stopwords from the text

import nltk
from nltk.corpus import stopwords

# Download the stopwords
nltk.download('stopwords')

# Define the stop words to remove
stop_words = set(stopwords.words('english'))

# Load the CSV file into a DataFrame
data = pd.read_csv('RawData.csv')

# Remove stopwords from the abstracts - split each abstract into individual words, filters out stopwords, and then joins the remaining words back into a single string
data['Scientific_Abstract'] = data['Scientific_Abstract'].apply(lambda x: ' '.join([word for word in x.split() if word not in stop_words]))

# Save the modified DataFrame to a new CSV file
data.to_csv('RawData_without_stopwords.csv', index=False)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# #3.Train and fit the model - import library e.g., Bertopic, extract abstracts as a list of strings, define the count vectorier, define a UMAP model and create a topic model

# %%
# Import necessary libraries
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer
from umap import UMAP

# Load data and extract abstracts
data = pd.read_csv("RawData_without_stopwords.csv")
abstracts = data['Scientific_Abstract'].astype(str).tolist()

# Initialize CountVectorizer and UMAP
vectorizer_model = CountVectorizer(ngram_range=(1, 2), stop_words="english")
umap_model = UMAP(random_state=42)

# Create and fit the BERTopic model
topic_model = BERTopic(umap_model=umap_model, vectorizer_model=vectorizer_model, language="english")
topics, probs = topic_model.fit_transform(abstracts)

# CountVectorizer - vectorizer converts textual data into numerical vectors, parameter (1,2) - the vectorizer will consider both unigrams (single words) and bigrams (pairs of consecutive words)
# Define a UMAP (Uniform Manifold Approximation and Projection) model for dimensionality reduction with fixed random state - DR technique used in data processing to simplify complex data by reducing the number of variables (dimensions)
#
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# # 4. Save the model and view results

# %%
# Save the model
from bertopic import BERTopic
topic_model.save("Screening_Model_v1")
# Out:
# 2024-07-26 10:43:35,618 - BERTopic - WARNING: When you use `pickle` to save/load a BERTopic model,please make sure that the environments in which you saveand load the model are **exactly** the same. The version of BERTopic,its dependencies, and python need to remain the same.

# %%
# Topics
topic_model.get_topic_info().head(50)
# Out:
#     Topic  Count                                               Name  \
# 0      -1    901                     -1_patients_care_health_people
# 1       0    147                     0_women_babies_pregnancy_birth
# 2       1    119                       1_patients_heart_blood_study
# 3       2    117                        2_asthma_patients_copd_lung
# 4       3     66                     3_research_health_local_public
# 5       4     58      4_antibiotics_antibiotic_infection_infections
# 6       5     56                   5_kidney_transplant_dialysis_ckd
# 7       6     54             6_vaccine_vaccination_vaccines_covid19
# 8       7     46                7_health_research_systems_community
# 9       8     45                    8_care_social care_social_older
# 10      9     45                 9_children_parents_families_health
# 11     10     45                    10_pain_spinal_patients_surgery
# 12     11     43                      11_eye_glaucoma_visual_vision
# 13     12     39              12_fracture_shoulder_surgery_patients
# 14     13     37        13_diabetes_programme_obesity_type diabetes
# 15     14     36          14_women_endometriosis_menopause_symptoms
# 16     15     36                    15_knee_hip_surgery_replacement
# 17     16     36              16_arthritis_ra_patients_inflammatory
# 18     17     35             17_surgery_surgical_patients_emergency
# 19     18     35                       18_alcohol_gambling_drug_use
# 20     19     34                    19_crc_bowel_colonoscopy_cancer
# 21     20     34          20_dementia_people dementia_carers_people
# 22     21     32                             21_nhs_staff_care_work
# 23     22     31                22_frailty_older_older people_frail
# 24     23     30                         23_dental_tooth_decay_oral
# 25     24     29       24_stroke_fatigue_stroke survivors_survivors
# 26     25     29                          25_food_foods_school_salt
# 27     26     27        26_palliative_palliative care_care_research
# 28     27     27            27_liver_liver disease_disease_research
# 29     28     26              28_survivors_health_violence_homeless
# 30     29     25                29_cancer_treatment_patients_tumour
# 31     30     24                        30_hnc_neck_thyroid_surgery
# 32     31     23  31_autistic_autism_autistic people_autistic ad...
# 33     32     23      32_multimorbidity_clusters_polypharmacy_mltcm
# 34     33     21                     33_eczema_skin_acne_treatments
# 35     34     21                34_hearing_language_children_speech
# 36     35     20  35_physical_physical activity_activity_interve...
# 37     36     20               36_prison_prisoners_prisons_selfharm
# 38     37     19                      37_ambulance_ed_ohca_patients
# 39     38     19                      38_smoking_quit_smoke_smokers
# 40     39     19                 39_cognitive_dementia_ad_diagnosis
# 41     40     19                    40_brain_delirium_injury_stroke
# 42     41     18             41_air_pollution_climate_air pollution
# 43     42     18             42_selfharm_suicide_young_young people
# 44     43     17        43_radiotherapy_breast_cancer_breast cancer
# 45     44     17                   44_psychosis_ptsd_therapy_voices
# 46     45     17                 45_ethnic_services_social_minority
# 47     46     17               46_care_general_continuity_practices
# 48     47     16             47_prostate_prostate cancer_cancer_men
# 49     48     16         48_young_mental health_mental_young people
#
#                                        Representation  \
# 0   [patients, care, health, people, research, stu...
# 1   [women, babies, pregnancy, birth, maternity, c...
# 2   [patients, heart, blood, study, ulcers, risk, ...
# 3   [asthma, patients, copd, lung, breathing, stud...
# 4   [research, health, local, public, public healt...
# 5   [antibiotics, antibiotic, infection, infection...
# 6   [kidney, transplant, dialysis, ckd, patients, ...
# 7   [vaccine, vaccination, vaccines, covid19, covi...
# 8   [health, research, systems, community, countri...
# 9   [care, social care, social, older, carers, res...
# 10  [children, parents, families, health, parentin...
# 11  [pain, spinal, patients, surgery, trial, cord,...
# 12  [eye, glaucoma, visual, vision, patients, oct,...
# 13  [fracture, shoulder, surgery, patients, fractu...
# 14  [diabetes, programme, obesity, type diabetes, ...
# 15  [women, endometriosis, menopause, symptoms, su...
# 16  [knee, hip, surgery, replacement, patients, kn...
# 17  [arthritis, ra, patients, inflammatory, treatm...
# 18  [surgery, surgical, patients, emergency, ssi, ...
# 19  [alcohol, gambling, drug, use, drinking, servi...
# 20  [crc, bowel, colonoscopy, cancer, fit, screeni...
# 21  [dementia, people dementia, carers, people, ca...
# 22  [nhs, staff, care, work, doctors, services, re...
# 23  [frailty, older, older people, frail, falls, p...
# 24  [dental, tooth, decay, oral, oral health, teet...
# 25  [stroke, fatigue, stroke survivors, survivors,...
# 26  [food, foods, school, salt, policy, healthy, a...
# 27  [palliative, palliative care, care, research, ...
# 28  [liver, liver disease, disease, research, cirr...
# 29  [survivors, health, violence, homeless, mental...
# 30  [cancer, treatment, patients, tumour, radiothe...
# 31  [hnc, neck, thyroid, surgery, patients, head n...
# 32  [autistic, autism, autistic people, autistic a...
# 33  [multimorbidity, clusters, polypharmacy, mltcm...
# 34  [eczema, skin, acne, treatments, trials, treat...
# 35  [hearing, language, children, speech, deaf, he...
# 36  [physical, physical activity, activity, interv...
# 37  [prison, prisoners, prisons, selfharm, staff, ...
# 38  [ambulance, ed, ohca, patients, cardiac, ambul...
# 39  [smoking, quit, smoke, smokers, nicotine, nrt,...
# 40  [cognitive, dementia, ad, diagnosis, biomarker...
# 41  [brain, delirium, injury, stroke, head, patien...
# 42  [air, pollution, climate, air pollution, healt...
# 43  [selfharm, suicide, young, young people, sh, d...
# 44  [radiotherapy, breast, cancer, breast cancer, ...
# 45  [psychosis, ptsd, therapy, voices, treatment, ...
# 46  [ethnic, services, social, minority, users, se...
# 47  [care, general, continuity, practices, practic...
# 48  [prostate, prostate cancer, cancer, men, biops...
# 49  [young, mental health, mental, young people, y...
#
#                                   Representative_Docs
# 0   [Research question We plan evaluate feasibilit...
# 1   [Aims This research assess new ways improve ac...
# 2   [Aim(s) research: The trial testing whether be...
# 3   [Asthma commonest long-term disease children U...
# 4   [What ‘Public Health Intervention Responsive S...
# 5   [Aims research This research aims find shortes...
# 6   [Aims research This study investigate whether ...
# 7   [Research question: Influenza, MenACWY, HPV CO...
# 8   [Background: Climate change projected increase...
# 9   [Background There little evidence Local Author...
# 10  [There growing concern prevalence mental healt...
# 11  [BACKGROUND In UK around 30,000 patients year ...
# 12  [What glaucoma? Glaucoma long-term eye disease...
# 13  [WHY IS THIS STUDY IMPORTANT? Tears shoulder r...
# 14  [Research question: Is lack engagement people ...
# 15  [BACKGROUND: Endometriosis affects ~176 millio...
# 16  [This research answer question: 'What importan...
# 17  [Rheumatoid arthritis, psoriatic arthritis ank...
# 18  [Background Each year NHS, 250,000 high-risk p...
# 19  [Research question What potential longer-term ...
# 20  [Background Colorectal cancer (CRC) 4th common...
# 21  [Background Dementia major health social care ...
# 22  [Background & Aims There continuing concerns N...
# 23  [As become older, nutrition critically importa...
# 24  [Unfortunately, child tooth decay major proble...
# 25  [We aim develop new approach testing ways help...
# 26  [RESEARCH QUESTION: How national School Food S...
# 27  [Research question How specialist palliative c...
# 28  [People may realise liver disease get severe i...
# 29  [Background: Domestic Abuse (DA) involves psyc...
# 30  [Aims Bowel, ovarian stomach cancer often spre...
# 31  [Research Question: Systematic review publishe...
# 32  [Research question What best intervention impr...
# 33  [Our overarching question is: &ldquo;How multi...
# 34  [Eczema common debilitating long-term skin dis...
# 35  [AIM OF THE RESEARCH: The aim research find wh...
# 36  [1. Aims Objectives To co-produce feasible int...
# 37  [Research question What frequency nature avoid...
# 38  [BACKGROUND Tackling health inequalities key p...
# 39  [Background Smoking pregnancy causes preventab...
# 40  [Background Early diagnosis dementia allows pr...
# 41  [We find whether tranexamic acid treatment old...
# 42  [Outdoor air pollution bad health linked heart...
# 43  [The aim study understand whether Distress Bri...
# 44  [Patients early stage breast cancer abnormal l...
# 45  [Background Hallucinations (hearing seeing thi...
# 46  [Research questions How help-seeking symptoms ...
# 47  [What problem? Older people living care homes ...
# 48  [Background Prostate cancer common cancer affe...
# 49  [In 2017, Department Health Department Educati...

# %%
# GET TOP 10 WORDS FOR TOPIC 2
topic_model.get_topic(2)[:10]
# Out:
# [('asthma', 0.02120914237822243),
#  ('patients', 0.014267967606431292),
#  ('copd', 0.011531489261033165),
#  ('lung', 0.011252867624491068),
#  ('breathing', 0.010133808065807059),
#  ('study', 0.009904345529261628),
#  ('breathlessness', 0.009698755212654515),
#  ('trial', 0.008856635458841794),
#  ('oxygen', 0.0075593345507311),
#  ('children', 0.007194941817355812)]

# %%
# BAR CHARTS OF TOP 20 TOPICS (10 WORDS)
topic_model.visualize_barchart (width=280, height=330, top_n_topics=20, n_words=10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2cc7d71f-c189-46a6-8de9-988ac52d15f1" class="plotly-graph-div" style="height:1650px; width:1120px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2cc7d71f-c189-46a6-8de9-988ac52d15f1")) {                    Plotly.newPlot(                        "2cc7d71f-c189-46a6-8de9-988ac52d15f1",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.00730155871346163,0.0077666707753611085,0.007933150497280099,0.007962068204018962,0.009107305336143935,0.009607352870532175,0.011237407078705661,0.013858274174935877,0.01612794852458782,0.02549970824176755],"y":["risk  ","study  ","parents  ","baby  ","care  ","maternity  ","birth  ","pregnancy  ","babies  ","women  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.0062479689043334645,0.006661735187098472,0.006675817188127104,0.006877357304348962,0.007125998428092931,0.007185837400295125,0.007647550912250309,0.010057757693244039,0.010657255096173527,0.01291219170862685],"y":["pressure  ","patient  ","months  ","af  ","risk  ","ulcers  ","study  ","blood  ","heart  ","patients  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.007194941817355812,0.0075593345507311,0.008856635458841794,0.009698755212654515,0.009904345529261628,0.010133808065807059,0.011252867624491068,0.011531489261033165,0.014267967606431292,0.02120914237822243],"y":["children  ","oxygen  ","trial  ","breathlessness  ","study  ","breathing  ","lung  ","copd  ","patients  ","asthma  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.
41, air, pollution, climate","27, liver, liver dise, disease","50, cancer, prehabilit, tya","31, autistic, autism, autistic p","34, hearing, language, children","57, adhd, children, children a","39, cognitive, dementia, ad","40, brain, delirium, injury","55, tvns, tremor, earswitch","44, psychosis, ptsd, therapy","49, antipsycho, clozapine, medication"],"y":["0 - Women & Pregnancy","23, dental, tooth, decay","38, smoking, quit, smoke","51, hiv, sexual, sexual hea","1 - Heart & Blood","2 - Asthma & breathing","5, kidney, transplant, dialysis","17, surgery, surgical, patients","56, trials, rcts, methods","3, research, health, local","7, health, research, systems","8, care, social car, social","28, survivors, health, violence","45, ethnic, services, social","4, antibiotic, antibiotic, infection","6, vaccine, vaccinatio, vaccines","9, children, parents, families","48, young, mental hea, mental","10, pain, spinal, patients","12, fracture, shoulder, surgery","15, knee, hip, surgery","58, children, ddh, ankle","11, eye, glaucoma, visual","16, arthritis, ra, patients","33, eczema, skin, acne","13, diabetes, programme, obesity","22, frailty, older, older peop","32, multimorbi, clusters, polypharma","35, physical, physical a, activity","14, women, endometrio, menopause","18, alcohol, gambling, drug","36, prison, prisoners, prisons","42, selfharm, suicide, young","19, crc, bowel, colonoscop","29, cancer, treatment, patients","30, hnc, neck, thyroid","43, radiothera, breast, cancer","47, prostate, prostate c, cancer","20, dementia, people dem, carers","53, disabiliti, learning d, people lea","21, nhs, staff, care","26, palliative, palliative, care","37, ambulance, ed, ohca","46, care, general, continuity","24, stroke, fatigue, stroke sur","52, abi, communicat, cpt","54, eip, psychosis, eip servic","59, relapse, anxiety, iapt","25, food, foods, school","41, air,  ...

# %%
# Topics visualisation
topic_model.visualize_documents(abstracts, topics=list(range(30)),custom_labels=True, height=600)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Hierarchical clustering
topic_model.visualize_hierarchy(custom_labels=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="65be3eae-d422-491f-9f34-244a5e15167b" class="plotly-graph-div" style="height:1100px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65be3eae-d422-491f-9f34-244a5e15167b")) {                    Plotly.newPlot(                        "65be3eae-d422-491f-9f34-244a5e15167b",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.7817994701534446,0.7817994701534446,0.0],"xaxis":"x","y":[-5.0,-5.0,-15.0,-15.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.5966305912925935,0.5966305912925935,0.0],"xaxis":"x","y":[-35.0,-35.0,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.5966305912925935,0.6427858161220225,0.6427858161220225,0.0],"xaxis":"x","y":[-40.0,-40.0,-55.0,-55.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.695743077198168,0.695743077198168,0.6427858161220225],"xaxis":"x","y":[-25.0,-25.0,-47.5,-47.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.550982692154989,0.550982692154989,0.0],"xaxis":"x","y":[-65.0,-65.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.550982692154989,0.7154169762310904,0.7154169762310904,0.0],"xaxis":"x","y":[-70.0,-70.0,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.695743077198168,0.7710866753314362,0.7710866753314362,0.7154169762310904],"xaxis":"x","y":[-36.25,-36.25,-77.5,-77.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.7018351506094007,0.7018351506094007,0.0],"xaxis":"x","y":[-115.0,-115.0,-125.0,-125.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.7576072552747617,0.7576072552747617,0.7018351506094007],"xaxis":"x","y":[-105.0,-105.0,-120.0,-120.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.7850134131270667,0.7850134131270667,0.7576072552747617],"xaxis":"x","y":[-95.0,-95.0,-112.5,-112.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.8332598511314379,0.8332598511314379,0.0],"xaxis":"x","y":[-135.0,-135.0,-145.0,-145.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.7850134131270667,0.8556217190139054,0.8556217190139054,0.8332598511314379],"xaxis":"x","y":[-103.75,-103.75,-140.0,-140.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.7710866753314362,0.8803458884654239,0.8803458884654239,0.8556217190139054],"xaxis":"x","y":[-56.875,-56.875,-121.875,-121.875],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.
,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[6.7661848068237305,8.875021934509277,9.246888160705566,-10.567191123962402,8.367276191711426,8.99148941040039,8.207625389099121,-10.670016288757324,-11.4072265625,6.5285162925720215,9.108829498291016,9.280404090881348,9.249363899230957,3.866642475128174,6.6802077293396,9.305602073669434,19.312183380126953,8.61863899230957,-9.664780616760254,20.200817108154297,-11.705693244934082,5.543910980224609,-11.461777687072754,6.598376274108887,-2.621197462081909,4.119504451751709,-11.780755996704102,-9.34257984161377,-10.323907852172852,19 ...

# %%
# Refine the algorithm by removing the outliers (EXCLUDE -1 UNKNOWN OUTLIERS)

# Load the data
abstract_data = pd.read_csv("RawData_without_stopwords.csv")

# Create a dataframe with project_ID, topic_ID and topic_probability
topic_df = pd.DataFrame({
    "ProjectID": abstract_data["ProjectID"],
    "Topic_ID": topics,
    "Topic_Prob": probs
})

# Remove outliers (Topic_ID = -1) and display a sample
filtered_df = topic_df[topic_df['Topic_ID'] != -1]
print(filtered_df.sample(30))
# Out:
#              ProjectID  Topic_ID  Topic_Prob
# 2149        NIHR205894        33    1.000000
# 2729  PB-PG-0817-20004         0    0.699548
# 1961        NIHR204706        24    0.822661
# 120      AI_AWARD01723        17    0.664356
# 1279        NIHR200490        16    0.816598
# 1312        NIHR200731        12    0.795619
# 2268        NIHR300504         2    1.000000
# 928         NIHR135278        26    1.000000
# 2769  PB-PG-1217-20018         2    0.758597
# 1183        NIHR156535        25    1.000000
# 891         NIHR134942         9    1.000000
# 391         NIHR128768        15    0.547581
# 1606        NIHR202753        52    1.000000
# 1283        NIHR200510        49    0.678455
# 2408        NIHR301634        51    1.000000
# 762         NIHR133168        46    0.945218
# 1573        NIHR202625        32    0.775402
# 1795        NIHR203681        36    1.000000
# 2209        NIHR206524        34    1.000000
# 470         NIHR129848        17    0.796308
# 314         NIHR127773        11    1.000000
# 2441        NIHR301808        39    0.481304
# 1691        NIHR203194        12    0.795619
# 1615        NIHR202788         1    1.000000
# 2233        NIHR300118         0    1.000000
# 2199        NIHR206404         0    1.000000
# 1826        NIHR204012         1    1.000000
# 2009        NIHR205012        24    0.939222
# 1245        NIHR200069        53    0.880484
# 2351        NIHR301225         1    1.000000

# %%
# Refine the algorithm for a particular topic (TOPIC 0 - Women & Pregnancy)

# Combine the topic IDs, topic probabilities, and the desired column from your source data
abstract_data = pd.read_csv ("RawData_without_stopwords.csv")

# Extract the ProjectID column
ProjectID = abstract_data["ProjectID"]

# create a new data frame with a project ID, topic ID, probability and the abstract filtered for topic ID0 which is women and baby
topic_df = pd.DataFrame({
"ProjectID": abstract_data["ProjectID"],
"Topic_ID": topics,
"Topic_Prob": probs,
"Document": abstracts
})
filtered_df = topic_df[topic_df['Topic_ID'] == 0]
print (filtered_df.sample(30))
# Out:
#                      ProjectID  Topic_ID  Topic_Prob  \
# 89                    17/89/07         0    1.000000
# 1744                NIHR203474         0    1.000000
# 1635                NIHR202920         0    0.843806
# 1656                NIHR203024         0    1.000000
# 238   ICA-CDRF-2018-04-ST2-020         0    0.836748
# 1624                NIHR202850         0    1.000000
# 1394                NIHR201424         0    1.000000
# 2707          PB-PG-0418-20005         0    1.000000
# 1325                NIHR200791         0    0.913488
# 455                 NIHR129715         0    0.717452
# 2610                NIHR302993         0    1.000000
# 2537                NIHR302513         0    0.713743
# 1337                NIHR200869         0    1.000000
# 607                 NIHR131339         0    0.685927
# 337                 NIHR127976         0    1.000000
# 847                 NIHR134293         0    0.654456
# 611                 NIHR131352         0    1.000000
# 2552                NIHR302565         0    0.926923
# 2228                NIHR300099         0    0.717452
# 2696          PB-PG-0317-20024         0    0.998511
# 863                 NIHR134535         0    1.000000
# 1103                NIHR153935         0    0.713529
# 1047                NIHR152188         0    1.000000
# 1525                NIHR202230         0    0.824942
# 247   ICA-CDRF-2018-04-ST2-042         0    0.708725
# 2233                NIHR300118         0    1.000000
# 1995                NIHR204956         0    1.000000
# 2299                NIHR300617         0    1.000000
# 564                 NIHR131021         0    1.000000
# 80                    17/75/09         0    1.000000
#
#                                                Document
# 89    This research focus babies born two six weeks ...
# 1744  Perinatal depression (PND) occurs pregnancy fi...
# 1635  Aim To transform proof-of-concept wireless vit...
# 1656  Research question What optimal process embeddi...
# 238   Worldwide 1-in-10 pregnancies end preterm birt...
# 1624  Background Preterm birth affects 60,000 pregna...
# 1394  Ten children born every day congenital cytomeg...
# 2707  Background National guidelines policy support ...
# 1325  Research question For women epilepsy aged 16-5...
# 455   WHAT IS THE PROBLEM? During pregnancy 8-24% wo...
# 2610  Background Hypertensive disease pregnancy (HDP...
# 2537  Background Cardiovascular disease (CVD) causes...
# 1337  Research Question Does universal primary preve...
# 607   1 5 women experience mental illness pregnancy ...
# 337   Background: In last months pregnancy, babies s...
# 847   We aim find pregnant women babies affected mat...
# 611   This study aims find drug antenatal corticoste...
# 2552  Research question: What impact midwifery suppo...
# 2228  Background Next-generation sequencing technolo...
# 2696  Background: Pregnancies women SCD associated h...
# 863   WHY ARE WE DOING THIS PROJECT? There lots chan...
# 1103  Background: Our goal many years improve life-l...
# 1047  One every 1000 babies born UK sustain brain dy...
# 1525  Research question How risk scoring planning to...
# 247   Background Trache-oesophageal fistula (TOF) Oe...
# 2233  My fellowship involve two studies intended imp...
# 1995  Research Question How make information resourc...
# 2299  Research question Can linked datasets routine ...
# 564   AIM To use know already existing research work...
# 80    Approximately one four women give birth caesar...

# %%
# Can I use the algorithm to predict the topic and probability for a new abstract (e.g. example 2)?

# Load and extract the abstract, convert the data to a string
new_abstracts = pd.read_csv("Example_2.csv")["Scientific_Abstract"].astype(str).tolist()

# Predict topics and probabilities for example, 2
predicted_topics, predicted_probs = topic_model.transform(new_abstracts)

# Print results - example two has been assigned topic 0 with a probability of 0.65 (and also topic 39 with 0.42)
print(predicted_topics, predicted_probs)
# Out:
# [0, 39] [0.65714371 0.42680116]
